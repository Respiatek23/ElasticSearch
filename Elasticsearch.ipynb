# %% [markdown]
# # Request on Elasticsearch using Python

# %% [markdown]
# ### Using Library Elasticsearch from:
#
# https://elasticsearch-py.readthedocs.io/en/7.10.0/index.html

# %%
# !pip install urllib3 -U
# Out:
# Requirement already up-to-date: urllib3 in c:\users\juan\anaconda3\lib\site-packages (2.2.1)

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(
    ['https://dd10ab92a777447c823f2241f941f0cb.us-central1.gcp.cloud.es.io:443'],
    basic_auth=('Admin', 'Password1'),
)
cloud_id='cf6846b64f08414bb8160517d240d3a5:dXMtY2VudHJhbDEuZ2NwLmNsb3VkLmVzLmlvJGRkMTBhYjkyYTc3NzQ0N2M4MjNmMjI0MWY5NDFmMGNiJDI2OGQyN2IzNmRhODQ5NTNiMWFlYzUxZjU0NTY0NTRh'
# Out:
# C:\Users\Juan\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# ignore 400 cause by IndexAlreadyExistsException when creating an index
es.indices.create(index='my-index-python', ignore=400)
# Out:
# <ipython-input-28-c94082b47ebb>:2: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.create(index='my-index-python', ignore=400)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my-index-python'})

# %%
# ignore 404 and 400
es.indices.delete(index='trafico-madrid', ignore=[400, 404])
# Out:
# <ipython-input-29-ebe46fdfc188>:2: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.delete(index='my-index-python', ignore=[400, 404])
# ObjectApiResponse({'acknowledged': True})

# %% [markdown]
# ### Making Requests

# %%
import requests
import json

# %%
url = 'https://dd10ab92a777447c823f2241f941f0cb.us-central1.gcp.cloud.es.io:443/'
username = 'Admin'
password = 'Password1'
index='trafico-madrid'
headers = {"Content-Type": "application/json"}
data= """{
  "settings": {
    "number_of_shards": 3,
    "number_of_replicas": 1
  }
}"""

# %%
response = requests.put(url+index, data=data, headers=headers, auth=(username, password))

# %% [markdown]
# # Actualizar settings

# %%
es.indices.delete(index='trafico-madrid', ignore=[400, 404])
url = 'https://dd10ab92a777447c823f2241f941f0cb.us-central1.gcp.cloud.es.io:443/'
username = 'Admin'
password = 'Password1'
index='trafico-madrid'
headers = {"Content-Type": "application/json"}
data= """{
  "settings": {
    "number_of_shards": 3,
    "index.mapping.total_fields.limit": 40,
    "number_of_replicas": 1
  }
}"""
response = requests.put(url+index, data=data, headers=headers, auth=(username, password))
res = response.json()
print(res)

# %% [markdown]
# # Obtener los settings con un get

# %%
index='trafico-madrid/_settings'
response=requests.get(url+index,headers=headers,auth=(username,password))
res=response.json()
print(res)
# Out:
# {'trafico-madrid': {'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}}, 'mapping': {'total_fields': {'limit': '40'}}, 'number_of_shards': '3', 'provided_name': 'trafico-madrid', 'creation_date': '1712145172600', 'number_of_replicas': '1', 'uuid': '3oxmclBiQ_Sn75uryADaBA', 'version': {'created': '8503000'}}}}}

# %% [markdown]
# # Crear un mapping

# %%
index = 'trafico-madrid'
if es.indices.exists(index=index):
    try:
        es.indices.delete(index=index)
        print(f"El índice '{index}' ha sido borrado correctamente.")
    except Exception as excep:
        print(f"Error al borrar el índice '{index}': {excep}")
else:
    print(f"El índice '{index}' no existe.")

mapping = {
    "mappings": {
        "properties": {
            "fecha_hora": {
                "type": "date",
                "format": "yyyy-MM-dd'T'HH:mm:ss'Z'"
            },
            "idelem": {
                "type": "keyword"
            },
            "descripcion": {
                "type": "text"
            },
            "accesoAsociado": {
                "type": "keyword"
            },
            "intensidad": {
                "type": "integer"
            },
            "ocupacion": {
                "type": "integer"
            },
            "carga": {
                "type": "integer"
            },
            "nivelServicio": {
                "type": "keyword"
            },
            "intensidadSat": {
                "type": "integer"
            },
            "error": {
                "type": "keyword"
            },
            "subarea": {
                "type": "keyword"
            },
            "coordenadas": {
                "type": "geo_point"
            }
        }
    }
}
try:
    es.indices.create(index=index, body=mapping)
    print(f"El índice '{index}' ha sido creado correctamente con el mapping actualizado.")
except Exception as excep:
    print(f"Error al crear el índice '{index}': {excep}")
# Out:
# El índice 'trafico-madrid' ha sido borrado correctamente.
# El índice 'trafico-madrid' ha sido creado correctamente con el mapping actualizado.

# %%
index_1="trafico-madrid/_doc"
data="""{
    "fecha_hora":"2015-01-01T12:10:25Z",
    "idelem":"11111",
    "descripcion":"No hay descripcion",
    "accesoAsociado":"222222",
    "intensidad":80,
    "ocupacion":1,
    "carga":4,
    "nivelServicio":0,
    "intensidadSat":3000,
    "error":"S",
    "subarea":"2222",
    "coordenadas":{
        "lat":28.04,
        "lon":13.56
    }
}"""



response=requests.post(url+index_1,data=data,headers=headers,auth=(username,password))
res=response.json()
print(res)
# Out:
# {'_index': 'trafico-madrid', '_id': 'wVjio44B1QPrHfuDuNIc', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}

# %%
index="trafico-madrid/_search"
data="""{
  "query": {
    "match": {
      "carga": "4"
    }
  }
}
"""
response=requests.get(url+index,data=data,headers=headers,auth=(username,password))
res=response.json()
print(res)
# Out:
# {'took': 1, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_index': 'trafico-madrid', '_id': 'wVjio44B1QPrHfuDuNIc', '_score': 1.0, '_source': {'fecha_hora': '2015-01-01T12:10:25Z', 'idelem': '11111', 'descripcion': 'No hay descripcion', 'accesoAsociado': '222222', 'intensidad': 80, 'ocupacion': 1, 'carga': 4, 'nivelServicio': 0, 'intensidadSat': 3000, 'error': 'S', 'subarea': '2222', 'coordenadas': {'lat': 28.04, 'lon': 13.56}}}]}}

# %%
index="trafico-madrid/_delete_by_query"
data="""{
  "query": {
    "match": {
      "_id": "wVjio44B1QPrHfuDuNIc"
    }
  }
}
"""
response=requests.post(url+index,data=data,headers=headers,auth=(username,password))
res=response.json()
print(res)
# Out:
# {'took': 16, 'timed_out': False, 'total': 1, 'deleted': 1, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []}

# %% [markdown]
# # 1.4: Consulta del API e ingesta de datos en ELASTICSEARCH

# %%
from xml.etree import ElementTree
response=requests.get("https://informo.madrid.es/informo/tmadrid/pm.xml")
root=ElementTree.fromstring(response.content)
fecha=root[0].text
print(fecha)
# Out:
# 08/04/2024 10:10:08

# %%
out=[]
for pm in root[1:-1]:
    d={}
    for i in pm:
        d[i.tag]=i.text
    out.append(d)

# %%
o=out[1:2]

# %%
procesar(o)

# %%
# Out:
# {'idelem': '6808', 'intensidad': '240', 'ocupacion': '3', 'carga': '20', 'nivelServicio': '0', 'velocidad': '38', 'error': 'N', 'st_x': '441891,868185106', 'st_y': '4481354,05712662'}

# %%
import datetime
import utm
from unidecode import unidecode

index = "trafico-madrid"

def procesar(data):
    
    for i in data:

        try:
            #fecha_hora = datetime.datetime.strptime(fecha, "%d-%m-%YT%H:%M:%SZ")
            idelem = i["idelem"]
            descripcion = unidecode(i["descripcion"].replace("Ø", "n.").replace("´","").replace("'",""))
            acceso_asociado = i["accesoAsociado"]
            try:
                intensidad = float(i["intensidad"])
            except KeyError:
                pass
            except:
                del i["intensidad"]
            try:
                ocupacion = float(i["ocupacion"])
            except KeyError:
                pass
            except:
                del i["ocupacion"]
            try:
                carga = float(i["carga"])
            except KeyError:
                pass
            except:
                del i["carga"]
            try:
                intensidad_sat = float(i["intensidadSat"])
            except KeyError:
                pass
            except:
                del i["intensidadSat"]
            
            nivel_servicio = i["nivelServicio"]
            error = i["error"]
            subarea = i["subarea"]

        
            latitud, longitud = utm.to_latlon(float(i["st_x"].replace(',', '.')), float(i["st_y"].replace(',', '.')), 30, 'T')

            # Lo que irá a Elastic
            data= {
                "idelem": idelem,
                "descripcion": descripcion,
                "accesoAsociado": acceso_asociado,
                "intensidad": intensidad,
                "ocupacion": ocupacion,
                "carga": carga,
                "nivelServicio": nivel_servicio,
                "intensidadSat": intensidad_sat,
                "error": error,
                "subarea": subarea,
                "coordenadas": {"lat": latitud, "lon": longitud}
            }
            es.index(index=index, body=data)
            
        except Exception as e:
            print("Error en el dato:")

# %%
index="trafico-madrid/_search"
data="""{
  "query": {
    "match": {
      "idelem": "7000"
    }
  }
}
"""
response=requests.get(url+index,data=data,headers=headers,auth=(username,password))
res=response.json()
print(res)
# Out:
# {'took': 1, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 8.003029, 'hits': [{'_index': 'trafico-madrid', '_id': 'dkcspY4BPZ1dPWaNmzAp', '_score': 8.003029, '_source': {'idelem': '7000', 'descripcion': '(MICRO)PSO. FERROVIARIOS n.3 (GIRO SENTIDO ALBERTO PALACIOS)', 'accesoAsociado': '0', 'intensidad': 42.0, 'ocupacion': 60.0, 'carga': 61.0, 'nivelServicio': '2', 'intensidadSat': 1500.0, 'error': 'N', 'subarea': '1738', 'coordenadas': {'lat': 40.34310942829344, 'lon': -3.7178268075649976}}}]}}

# %% [markdown]
# # 1.6: Ingesta de muchos elementos de manera simultánea

# %%
import json
def njsonear(df):
    mjson=""
    for i in df:
        mjson+='{ "index": {"_index": "trafico-madrid"}}\n'
        mjson+=json.dumps(i) +'\n'
    return mjson

# %%
mjson=njsonear(out)

# %%
url = 'https://dd10ab92a777447c823f2241f941f0cb.us-central1.gcp.cloud.es.io:443/'
index='trafico-madrid'
api="""/_bulk"""
headers={"Content-type":"application/json"}
response=requests.post(url+index+api,data=mjson,headers=headers,auth=(username,password))
response.json()
# Out:
# {'errors': False,
#  'took': 394,
#  'items': [{'index': {'_index': 'trafico-madrid',
#     '_id': 'eEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4486,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'eUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4487,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'ekfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4488,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'e0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4489,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'fEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4490,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'fUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4491,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'fkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4492,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'f0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4493,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'gEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4494,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'gUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4495,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'gkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4496,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'g0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4497,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'hEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4498,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'hUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4499,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'hkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4500,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'h0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4501,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'iEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4502,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'iUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4503,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'ikfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4504,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'i0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4505,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'jEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4506,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'jUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4507,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'jkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4508,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'j0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4509,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'kEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4510,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'kUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4511,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'kkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4512,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'k0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4513,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'lEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4514,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'lUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4515,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'lkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4516,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'l0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4517,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'mEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4518,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'mUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4519,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'mkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4520,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'm0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4521,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'nEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4522,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'nUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4523,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'nkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4524,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'n0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4525,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'oEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4526,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'oUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4527,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'okfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4528,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'o0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4529,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'pEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4530,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'pUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4531,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'pkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4532,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'p0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4533,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'qEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4534,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'qUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4535,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'qkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4536,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'q0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4537,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'rEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4538,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'rUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4539,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'rkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4540,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'r0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4541,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'sEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4542,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'sUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4543,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'skfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4544,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 's0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4545,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'tEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4546,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'tUfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4547,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'tkfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4548,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 't0favI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4549,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 'uEfavI4BPZ1dPWaNJkG4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4550,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'trafico-madrid',
#     '_id': 